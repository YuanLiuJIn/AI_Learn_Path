# %%
from IPython.display import Image

# %% [markdown]
# ### variables & distributions

# %% [markdown]
# - 随机变量：样本空间 $\Omega$ 映射到实数集 $\mathbb R$ 的函数
# - 概率分布：关于随机变量 $X$ 的概率函数

# %% [markdown]
# ### condition & joint

# %%
Image(url='../figs/trajectory.png', width=400)
# Out:
# <img src="../figs/trajectory.png" width="400"/>

# %% [markdown]
# $$
# \begin{split}
# p_\theta(\tau)&=p(s_1)p_\theta(a_1|s_1)p(s_2|s_1,a_1)p_\theta(a_2|s_2)p(s_3|s_2,a_2)\cdots\\
# &=p(s_1)\Pi_{t=1}^Tp_\theta(a_t|s_t)p(s_{t+1}|s_t,a_t)
# \end{split}
# $$
# - policy ($p_\theta(a_t|s_t)$) 来自于 agent
# - transition ($p(s_{t+1}|s_t,a_t)$) 来自于 environment
