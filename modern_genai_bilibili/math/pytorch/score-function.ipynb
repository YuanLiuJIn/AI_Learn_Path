# %% [markdown]
# ### score function 的求导对象

# %% [markdown]
# - pg：对参数求导，$\nabla_\theta \log p_\theta(x)$
#     - $\nabla_\theta \log \pi_\theta(a|s)$
# - diffusion/score matching：对 $x$ 求导，$\nabla_x\log p_\theta(x)$
