# %% [markdown]
# - MLX 就像是披着 PyTorch 易用外衣的 JAX，并且它的地基是直接锚定在 Apple 芯片的统一内存架构（UMA）之上的。
# - mlx vs. core ml
#     - MLX 不等于 Core ML。两者都在 Apple 的机器学习版图里，但侧重点不同。Core ML 更偏向把模型集成进 app 做高效部署；而 Apple 对 MLX 的描述更偏向 在 Mac 上实验、训练、微调开源模型，尤其适合本地跑 LLM 这类工作。
# - mlx-lm for llm

# %% [markdown]
# ### qwen3-asr-1.7b

# %% [markdown]
# > mlx 版本
