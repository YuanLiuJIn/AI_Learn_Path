# %% [markdown]
# > 反向传播的本质是乘雅克比矩阵。

# %% [markdown]
# > 推一推 FFN 的 Jacobian
#
# $$J_{\mathrm{FFN}}^{(t,s)}=\delta_{ts}W_2\operatorname{diag}\!\bigl(\sigma'(z_t)\bigr)W_1$$
#
# 标准的、逐位置计算的两层 FFN：其中 $\delta_{ts}$ 表明：普通 FFN 不混合不同 token，只有 \(t=s\) 的对角块非零。
