# %% [markdown]
# - 主 agent loop：用 memory
# - Stage 1 loop：从旧对话提取 raw memory
# - Phase 2 agent loop：把 raw memory 整理成长期 memory 文档

# %% [markdown]
# ### 主对话 agent loop

# %% [markdown]
# ### Stage 1 Extraction Loop：写入 raw memory

# %% [markdown]
# ### Phase 2 Consolidation Agent Loop：更新 MEMORY.md / summary
